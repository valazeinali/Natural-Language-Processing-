# %%
source("progGra.R")

# %% [markdown]
# ## Graph for copying C6

# %%
ReadData("/data/critt/tprdb/CS/CPS20/Tables/P17_C6")
ProgGraph(X1=36500,X2=38000,Y1=102, Y2=120,au=1,seg = 0)
dev.new(width=100, height=100)
# Out:
# Reading Keyboard data: /data/critt/tprdb/CS/CPS20/Tables/P17_C6 .kd
# Reading Fixation data: /data/critt/tprdb/CS/CPS20/Tables/P17_C6 .fd
# Reading Fixation Units: /data/critt/tprdb/CS/CPS20/Tables/P17_C6 .fu
# Reading Production Units: /data/critt/tprdb/CS/CPS20/Tables/P17_C6 .pu
# Reading Activity Units: /data/critt/tprdb/CS/CPS20/Tables/P17_C6 .au
# Reading Source Text: /data/critt/tprdb/CS/CPS20/Tables/P17_C6 .st
# Fixation table empty: cannot plot fixations
# plot without title

# %% [markdown]
# ## Graph for copying C5

# %%
ReadData("/data/critt/tprdb/CS/CPS20/Tables/P17_C5")
ProgGraph(X1=36500,X2=38000,Y1=102, Y2=120,au=1,seg = 0)
dev.new(width=100, height=100)
# Out:
# Reading Keyboard data: /data/critt/tprdb/CS/CPS20/Tables/P17_C5 .kd
# Reading Fixation data: /data/critt/tprdb/CS/CPS20/Tables/P17_C5 .fd
# Reading Fixation Units: /data/critt/tprdb/CS/CPS20/Tables/P17_C5 .fu
# Reading Production Units: /data/critt/tprdb/CS/CPS20/Tables/P17_C5 .pu
# Reading Activity Units: /data/critt/tprdb/CS/CPS20/Tables/P17_C5 .au
# Reading Source Text: /data/critt/tprdb/CS/CPS20/Tables/P17_C5 .st
# Fixation table empty: cannot plot fixations
# plot without title

# %% [markdown]
# ## Graph for H1

# %%
ReadData("/data/critt/tprdb/CS/CPS20/Tables/P17_H1")
ProgGraph(X1=365000,X2=380000,Y1=102, Y2=120,au=1,seg = 0)
dev.new(width=100, height=100)
# Out:
# Reading Keyboard data: /data/critt/tprdb/CS/CPS20/Tables/P17_H1 .kd
# Reading Fixation data: /data/critt/tprdb/CS/CPS20/Tables/P17_H1 .fd
# Reading Fixation Units: /data/critt/tprdb/CS/CPS20/Tables/P17_H1 .fu
# Reading Production Units: /data/critt/tprdb/CS/CPS20/Tables/P17_H1 .pu
# Reading Activity Units: /data/critt/tprdb/CS/CPS20/Tables/P17_H1 .au
# Reading Source Text: /data/critt/tprdb/CS/CPS20/Tables/P17_H1 .st
# Fixation table empty: cannot plot fixations
# plot without title

# %% [markdown]
# ## Graph for H2

# %%
ReadData("/data/critt/tprdb/CS/CPS20/Tables/P17_H2")
ProgGraph(X1=165000,X2=460000,Y1=102, Y2=120,au=1,seg = 0)
dev.new(width=1000, height=1000)
# Out:
# Reading Keyboard data: /data/critt/tprdb/CS/CPS20/Tables/P17_H2 .kd
# Reading Fixation data: /data/critt/tprdb/CS/CPS20/Tables/P17_H2 .fd
# Reading Fixation Units: /data/critt/tprdb/CS/CPS20/Tables/P17_H2 .fu
# Reading Production Units: /data/critt/tprdb/CS/CPS20/Tables/P17_H2 .pu
# Reading Activity Units: /data/critt/tprdb/CS/CPS20/Tables/P17_H2 .au
# Reading Source Text: /data/critt/tprdb/CS/CPS20/Tables/P17_H2 .st
# Fixation table empty: cannot plot fixations
# plot without title

# %% [markdown]
# ## Graph for U3

# %%
ReadData("/data/critt/tprdb/CS/CPS20/Tables/P17_U3")
ProgGraph(X1=16500,X2=98000,Y1=102, Y2=120,au=1,seg = 0)
dev.new(width=100, height=100)
# Out:
# Reading Keyboard data: /data/critt/tprdb/CS/CPS20/Tables/P17_U3 .kd
# Reading Fixation data: /data/critt/tprdb/CS/CPS20/Tables/P17_U3 .fd
# Reading Fixation Units: /data/critt/tprdb/CS/CPS20/Tables/P17_U3 .fu
# Reading Production Units: /data/critt/tprdb/CS/CPS20/Tables/P17_U3 .pu
# Reading Activity Units: /data/critt/tprdb/CS/CPS20/Tables/P17_U3 .au
# Reading Source Text: /data/critt/tprdb/CS/CPS20/Tables/P17_U3 .st
# Fixation table empty: cannot plot fixations
# plot without title

# %% [markdown]
# ## Graph for U4

# %%
ReadData("/data/critt/tprdb/CS/CPS20/Tables/P17_U4")
ProgGraph(X1=26500,X2=88000,Y1=102, Y2=120,au=1,seg = 0)
dev.new(width=100, height=100)
# Out:
# Reading Keyboard data: /data/critt/tprdb/CS/CPS20/Tables/P17_U4 .kd
# Reading Fixation data: /data/critt/tprdb/CS/CPS20/Tables/P17_U4 .fd
# Reading Fixation Units: /data/critt/tprdb/CS/CPS20/Tables/P17_U4 .fu
# Reading Production Units: /data/critt/tprdb/CS/CPS20/Tables/P17_U4 .pu
# Reading Activity Units: /data/critt/tprdb/CS/CPS20/Tables/P17_U4 .au
# Reading Source Text: /data/critt/tprdb/CS/CPS20/Tables/P17_U4 .st
# Fixation table empty: cannot plot fixations
# plot without title

# %% [markdown]
# ## Below for copying

# %%
options(repr.plot.width=50, repr.plot.height=30) # to resize R-plot in juypter notebook
ReadData("/data/critt/tprdb/CS/CPS20/Tables/P17_C6")
ProgGraph()
# Out:
# Reading Keyboard data: /data/critt/tprdb/CS/CPS20/Tables/P17_C6 .kd
# Reading Fixation data: /data/critt/tprdb/CS/CPS20/Tables/P17_C6 .fd
# Reading Fixation Units: /data/critt/tprdb/CS/CPS20/Tables/P17_C6 .fu
# Reading Production Units: /data/critt/tprdb/CS/CPS20/Tables/P17_C6 .pu
# Reading Activity Units: /data/critt/tprdb/CS/CPS20/Tables/P17_C6 .au
# Reading Source Text: /data/critt/tprdb/CS/CPS20/Tables/P17_C6 .st
# Fixation table empty: cannot plot fixations
# plot without title

# %%
options(repr.plot.width=50, repr.plot.height=30) # to resize in juypter notebook
ReadData("/data/critt/tprdb/CS/CPS20/Tables/P17_C5")
ProgGraph()
# Out:
# Reading Keyboard data: /data/critt/tprdb/CS/CPS20/Tables/P17_C5 .kd
# Reading Fixation data: /data/critt/tprdb/CS/CPS20/Tables/P17_C5 .fd
# Reading Fixation Units: /data/critt/tprdb/CS/CPS20/Tables/P17_C5 .fu
# Reading Production Units: /data/critt/tprdb/CS/CPS20/Tables/P17_C5 .pu
# Reading Activity Units: /data/critt/tprdb/CS/CPS20/Tables/P17_C5 .au
# Reading Source Text: /data/critt/tprdb/CS/CPS20/Tables/P17_C5 .st
# Fixation table empty: cannot plot fixations
# plot without title

# %% [markdown]
# ## Paraphrasing below

# %%
options(repr.plot.width=50, repr.plot.height=30) # to resize in juypter notebook
ReadData("/data/critt/tprdb/CS/CPS20/Tables/P17_H1")
ProgGraph()
# Out:
# Reading Keyboard data: /data/critt/tprdb/CS/CPS20/Tables/P17_H1 .kd
# Reading Fixation data: /data/critt/tprdb/CS/CPS20/Tables/P17_H1 .fd
# Reading Fixation Units: /data/critt/tprdb/CS/CPS20/Tables/P17_H1 .fu
# Reading Production Units: /data/critt/tprdb/CS/CPS20/Tables/P17_H1 .pu
# Reading Activity Units: /data/critt/tprdb/CS/CPS20/Tables/P17_H1 .au
# Reading Source Text: /data/critt/tprdb/CS/CPS20/Tables/P17_H1 .st
# Fixation table empty: cannot plot fixations
# plot without title

# %%
options(repr.plot.width=50, repr.plot.height=30) # to resize in juypter notebook
ReadData("/data/critt/tprdb/CS/CPS20/Tables/P17_H2")
ProgGraph()
# Out:
# Reading Keyboard data: /data/critt/tprdb/CS/CPS20/Tables/P17_H2 .kd
# Reading Fixation data: /data/critt/tprdb/CS/CPS20/Tables/P17_H2 .fd
# Reading Fixation Units: /data/critt/tprdb/CS/CPS20/Tables/P17_H2 .fu
# Reading Production Units: /data/critt/tprdb/CS/CPS20/Tables/P17_H2 .pu
# Reading Activity Units: /data/critt/tprdb/CS/CPS20/Tables/P17_H2 .au
# Reading Source Text: /data/critt/tprdb/CS/CPS20/Tables/P17_H2 .st
# Fixation table empty: cannot plot fixations
# plot without title

# %% [markdown]
# ## Summarizations below

# %%
options(repr.plot.width=50, repr.plot.height=30) # to resize in juypter notebook
ReadData("/data/critt/tprdb/CS/CPS20/Tables/P17_U3")
ProgGraph()
# Out:
# Reading Keyboard data: /data/critt/tprdb/CS/CPS20/Tables/P17_U3 .kd
# Reading Fixation data: /data/critt/tprdb/CS/CPS20/Tables/P17_U3 .fd
# Reading Fixation Units: /data/critt/tprdb/CS/CPS20/Tables/P17_U3 .fu
# Reading Production Units: /data/critt/tprdb/CS/CPS20/Tables/P17_U3 .pu
# Reading Activity Units: /data/critt/tprdb/CS/CPS20/Tables/P17_U3 .au
# Reading Source Text: /data/critt/tprdb/CS/CPS20/Tables/P17_U3 .st
# Fixation table empty: cannot plot fixations
# plot without title

# %%
options(repr.plot.width=50, repr.plot.height=30) # to resize in juypter notebook
ReadData("/data/critt/tprdb/CS/CPS20/Tables/P17_U4")
ProgGraph()
# Out:
# Reading Keyboard data: /data/critt/tprdb/CS/CPS20/Tables/P17_U4 .kd
# Reading Fixation data: /data/critt/tprdb/CS/CPS20/Tables/P17_U4 .fd
# Reading Fixation Units: /data/critt/tprdb/CS/CPS20/Tables/P17_U4 .fu
# Reading Production Units: /data/critt/tprdb/CS/CPS20/Tables/P17_U4 .pu
# Reading Activity Units: /data/critt/tprdb/CS/CPS20/Tables/P17_U4 .au
# Reading Source Text: /data/critt/tprdb/CS/CPS20/Tables/P17_U4 .st
# Fixation table empty: cannot plot fixations
# plot without title

# %% [markdown]
# ###### When we analyze copying, paraphrasing, and summarization
# ##### Paper report link:
